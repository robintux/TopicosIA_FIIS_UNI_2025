# %% [markdown]
# # Modulo numpy

# %%
# Cargamos el modulo
import numpy as np

# %%
# Documentacion del modulo numpy
help(np)

# %%
# Elementos que componen al modulo numpy
dir(np)

# %%
#
help(np.ERR_LOG)

# %%
np.ERR_LOG
# Out:
# 5

# %%
#
help(np.True_)

# %%
# Recuerda que el modulo numpy esta compuesto por una serie de submodulos
dir(np)

# %%
# Documentacion del submodulo random
help(np.random)

# %%
# LIsta de elementos que componen al submodulo random
dir(np.random)

# %%
# Documentacion de la funcion rayleigh
help(np.random.rayleigh)

# %% [markdown]
# # El modulo scipy

# %%
# carguemos el modulo scipy
import scipy

# %%
# Documentacion de scipy
help(scipy)

# %%
# En vista de que es necesario importar los submodulos de manera explicita
import scipy.optimize
help(scipy.optimize)

# %%
# Acceso a los elementos que componen al submodulo optimize
dir(scipy.optimize)
